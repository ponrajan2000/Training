# %% [markdown]
# ### 1. Create a string and convert it to lowercase using lower().

# %%
# Write your answer here

# %% [markdown]
# ### 2. Create a string and convert it to uppercase using upper().

# %%
# Write your answer here

# %% [markdown]
# ### 3. Check whether a string is completely lowercase using islower().

# %%
# Write your answer here

# %% [markdown]
# ### 4. Check whether a string is completely uppercase using isupper().

# %%
# Write your answer here

# %% [markdown]
# ### 5. Convert the first character of a string to uppercase using capitalize().

# %%
# Write your answer here

# %% [markdown]
# ### 6. Convert the first letter of every word to uppercase using title().

# %%
# Write your answer here

# %% [markdown]
# ### 7. Swap uppercase letters to lowercase and vice versa using swapcase().

# %%
# Write your answer here

# %% [markdown]
# ### 8. Check if a string contains only alphabets using isalpha().

# %%
# Write your answer here

# %% [markdown]
# ### 9. Check if a string contains only digits using isdigit().

# %%
# Write your answer here

# %% [markdown]
# ### 10. Check if a string contains only alphanumeric characters using isalnum().

# %%
# Write your answer here

# %% [markdown]
# ### 11. Check if a string contains only whitespace using isspace().

# %%
# Write your answer here

# %% [markdown]
# ### 12. Write a program to validate whether a user input is numeric.

# %%
# Write your answer here

# %% [markdown]
# ### 13. Count how many times a character appears in a string using count().

# %%
# Write your answer here

# %% [markdown]
# ### 14. Find the position of a word using find().

# %%
# Write your answer here

# %% [markdown]
# ### 15. Find the position of a word using index().

# %%
# Write your answer here

# %% [markdown]
# ### 16. Test what happens when find() does not locate a substring.

# %%
# Write your answer here

# %% [markdown]
# ### 17. Extract a substring using slicing.

# %%
# Write your answer here

# %% [markdown]
# ### 18. Replace a word in a sentence using replace().

# %%
# Write your answer here

# %% [markdown]
# ### 19. Remove leading and trailing spaces using strip().

# %%
# Write your answer here

# %% [markdown]
# ### 20. Remove only leading spaces using lstrip().

# %%
# Write your answer here

# %% [markdown]
# ### 21. Remove only trailing spaces using rstrip().

# %%
# Write your answer here

# %% [markdown]
# ### 22. Remove all occurrences of a specific character using replace().

# %%
# Write your answer here

# %% [markdown]
# ### 23. Split a sentence into words using split().

# %%
# Write your answer here

# %% [markdown]
# ### 24. Split a string using a custom delimiter (e.g., comma).

# %%
# Write your answer here

# %% [markdown]
# ### 25. Join a list of words into a single string using join().

# %%
# Write your answer here

# %% [markdown]
# ### 26. Convert a comma-separated string into a list.

# %%
# Write your answer here

# %% [markdown]
# ### 27. Check whether a string starts with a specific word using startswith().

# %%
# Write your answer here

# %% [markdown]
# ### 28. Check whether a string ends with a specific word using endswith().

# %%
# Write your answer here

# %% [markdown]
# ### 29. Check whether a string is a palindrome (ignore case).

# %%
# Write your answer here

# %% [markdown]
# ### 30. Count the number of uppercase and lowercase letters in a string.

# %%
# Write your answer here
