# %%
city = "Paris"
year = 1889
monument = "Eiffel Tower"
height = 300
# Print: The Eiffel Tower in Paris was built in 1889 and stands 300 meters tall. This is for testing #2

# %%
print("The",monument,"in",city,"was built in",year,"and stands",height, "meters tall.")
# Out:
# The Eiffel Tower in Paris was built in 1889 and stands 300 meters tall.

# %%
movie = "Inception"
director = "Christopher Nolan"
year = 2010
rating = 8.8
# Print: Inception, directed by Christopher Nolan, was released in 2010 and has a rating of 8.8.

# %%
print(movie+",","directed by",director+",","was released in",year,"and has a rating of",str(rating)+".")
# Out:
# Inception, directed by Christopher Nolan, was released in 1991 and has a rating of 8.8.

# %%
book = "1984"
author = "George Orwell"
published = 1949
genre = "Dystopian"
# Print: 1984 is a Dystopian novel written by George Orwell and published in 1949.

# %%
print(book,"is a",genre,"novel written by",author,"and","published in",str(published)+".")
# Out:
# 1984 is a Dystopian novel written by George Orwell and published in 1949.

# %%
language = "Python"
creator = "Guido van Rossum"
year = 1991
version = 3.10
# Print: Python was created by Guido van Rossum in 1991, and the current version is 3.10.

# %%
print(language,"was created by",creator,"in",str(year)+",","and the current version is",format(version,".2f")+".")
# Out:
# Python was created by Guido van Rossum in 1991, and the current version is 3.10.

# %%
planet = "Mars"
moons = 2
diameter_km = 6779
# Print: Mars has 2 moons and a diameter of 6779 kilometers.

# %%
print(planet,"has",moons,"moons","and a diameter of",diameter_km,"kilometers.")
# Out:
# Mars has 2 moons and a diameter of 6779 kilometers.

# %%
company = "Tesla"
ceo = "Elon Musk"
founded = 2003
industry = "Automotive"
# Print: Tesla is an Automotive company founded in 2003, currently led by Elon Musk.

# %%
print(company,"is an",industry,"company founded in",str(founded)+",","currently led by",ceo+".")
# Out:
# Tesla is an Automotive company founded in 2003, currently led by Elon Musk.

# %%
festival = "Diwali"
country = "India"
month = "October"
duration_days = 5
# Print: Diwali is a 5-day festival celebrated in India during October.

# %%
print(festival,"is a",str(duration_days)+"-day","festival celebrated in",country,"during",month)
# Out:
# Diwali is a 5-day festival celebrated in India during October

# %%
country = "Japan"
capital = "Tokyo"
population_millions = 126
currency = "Yen"
# Print: Japan's capital is Tokyo, population is 126 million, and the currency is Yen.

# %%
print(country+"'s","capital is",capital+",","population is",population_millions,"million, and the currency is",currency+".")
# Out:
# Japan's capital is Tokyo, population is 126 million, and the currency is Yen.

# %%
device = "iPhone"
brand = "Apple"
release_year = 2007
version = "15 Pro"
# Print: Apple released the first iPhone in 2007, and the latest version is 15 Pro.

# %%
print(brand,"released the first",device,"in",str(release_year)+",","and the latest version is",version+".")
# Out:
# Apple released the first iPhone in 2007, and the latest version is 15 Pro.

# %%
car = "Model S"
manufacturer = "Tesla"
range_km = 652
top_speed = 250
# Print: The Tesla Model S has a range of 652 km and a top speed of 250 km/h.

# %%
print("The",manufacturer,car,"has a range of",range_km,"km and a top speed of",top_speed,"km/h.")
# Out:
# The Tesla Model S has a range of 652 km and a top speed of 250 km/h.

# %%
animal = "Elephant"
habitat = "Forest"
lifespan_years = 70
weight_tons = 6
# Print: Elephants live in forests, weigh around 6 tons, and can live up to 70 years.

# %%
print(animal,"live in",habitat+",","weigh around",weight_tons,"tons, and can live up to",lifespan_years,"years.")
# Out:
# Elephant live in Forest, weigh around 6 tons, and can live up to 70 years.

# %%
game = "Chess"
players = 2
origin = "India"
pieces = 32
# Print: Chess is a 2-player game that originated in India and uses 32 pieces.

# %%
print(game,"is a",str(players)+"-player","game that originated in",origin,"and uses",pieces,"pieces.")
# Out:
# Chess is a 2-player game that originated in India and uses 32 pieces.

# %%
app = "Instagram"
owner = "Meta"
launched = 2010
users_billion = 2
# Print: Instagram, owned by Meta, was launched in 2010 and has over 2 billion users.

# %%
print(app+",","owned by",owner+",","was launched in",launched, "in 2010 and has over", users_billion,"users.")
# Out:
# Instagram, owned by Meta, was launched in 2010 in 2010 and has over 2 users.

# %%
river = "Nile"
length_km = 6650
continent = "Africa"
passes_countries = 11
# Print: The Nile River in Africa is 6650 km long and flows through 11 countries.

# %%
print("The",river,"River in",continent,"is",length_km,"km long and flows through",passes_countries,"countries.")
# Out:
# The Nile River in Africa is 6650 km long and flows through 11 countries

# %%
robot = "Sophia"
created_by = "Hanson Robotics"
year = 2016
country = "Hong Kong"
# Print: Sophia the robot was created by Hanson Robotics in 2016 in Hong Kong.

# %%
print(robot,"the robot was created by",created_by,"in",year,"in",country+".")
# Out:
# Sophia the robot was created by Hanson Robotics in 2016 in Hong Kong.

# %%
building = "Burj Khalifa"
height_m = 828
city = "Dubai"
opened_year = 2010
# Print: Burj Khalifa in Dubai was opened in 2010 and is 828 meters tall.

# %%
print(building,"in",city,"was opened in",opened_year,"and is",height_m,"meters tall.")
# Out:
# Burj Khalifa in Dubai was opened in 2010 and is 828 meters tall.

# %%
continent = "Antarctica"
temp = -60
inhabitants = 0
stations = 70
# Print: Antarctica has no permanent inhabitants, 70 research stations, and average temperatures of -60°C.

# %%
print(continent,"has no permanent inhabitants",stations,"research stations","and average temperatures of",str(temp)+"\u00B0C.")
# Out:
# Antarctica has no permanent inhabitants 70 research stations and average temperatures of -60°C.

# %%
dish = "Pizza"
origin = "Italy"
main_ingredient = "Dough"
serving_temp = "Hot"
# Print: Pizza, a hot dish from Italy, is made mainly from dough.

# %%
print(dish+",","a",serving_temp,"dish from",origin+",","is made mainly from",main_ingredient)
# Out:
# Pizza, a Hot dish from Italy, is made mainly from Dough

# %%
space_mission = "Apollo 11"
year = 1969
astronaut = "Neil Armstrong"
achievement = "first moon landing"
# Print: Apollo 11 achieved the first moon landing in 1969, led by Neil Armstrong.

# %%
print(space_mission,"achieved the",achievement,"in",str(year)+",",astronaut+".")
# Out:
# Apollo 11 achieved the first moon landing in 1969, Neil Armstrong.

# %%
tree = "Banyan"
country = "India"
lifespan_years = 200
type = "Ficus"
# Print: The Banyan tree, a Ficus species from India, can live for over 200 years.

# %%
print("The",tree,"tree,","a",type,"species from",country+",","can live for over",lifespan_years,"years.")
# Out:
# The Banyan tree, a Ficus species from India, can live for over 200 years.
