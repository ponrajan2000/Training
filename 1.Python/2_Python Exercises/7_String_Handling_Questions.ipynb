# %% [markdown]
# ### 1. Create a string and print it.

# %%
# Write your answer here
a = input("Enter the Name")
print(a)
# Out:
# Enter the Name Ponrajan
# Ponrajan

# %% [markdown]
# ### 2. Take a string and print its length.

# %%
# Write your answer here
a = input("Enter the Name")
print(len(a))
# Out:
# Enter the Name fsdf
# 4

# %% [markdown]
# ### 3. Convert a string to uppercase.

# %%
# Write your answer here
a = input("Enter the Name")
print(a.upper())
# Out:
# Enter the Name sdfsd
# SDFSD

# %% [markdown]
# ### 4. Convert a string to lowercase.

# %%
# Write your answer here
a = input("Enter the Name")
print(a.lower())
# Out:
# Enter the Name JKKJH
# jkkjh

# %% [markdown]
# ### 5. Check whether a given substring exists in a string.

# %%
# Write your answer here
a = input("Enter the Name")
b = input("Enter the Substring")
if b in a:
    print("Exist")
else:
    print("Not Exist")

if a.find(b) >= 0:
    print("Exist")
else:
    print("Not Exist")
# Out:
# Enter the Name ponrajan
# Enter the Substring sdasd
# Not Exist
# Not Exist

# %% [markdown]
# ### 6. Count how many times a character appears in a string.

# %%
# Write your answer here
a = input("Enter the Name")
b = input("Enter the Character")
j = 0
for i in a:
    if i == b:
        j = j + 1
print(j)
# Out:
# Enter the Name ponrasas
# Enter the Character 2
# 0

# %% [markdown]
# ### 7. Replace a word in a string with another word.

# %%
# Write your answer here
a = input("Enter the Name")
b = input("Enter the Find Character")
c = input("Enter the Replace Character")
print(a.replace(b,c))
# Out:
# Enter the Name Ponrajan
# Enter the Fine Character a
# Enter the Replace Character z
# Ponrzjzn

# %% [markdown]
# ### 8. Remove leading and trailing spaces from a string.

# %%
# Write your answer here
a  = "    Ponrajan"
b  = "    Ponrajan          "
print(a.lstrip())
print(b.rstrip())
print(b.strip())
# Out:
# Ponrajan
#     Ponrajan
# Ponrajan

# %% [markdown]
# ### 9. Split a sentence into words.

# %%
# Write your answer here
a = "Ponraja@is@good@boy"
print(a.split("@"))
# Out:
# ['Ponraja', 'is', 'good', 'boy']

# %% [markdown]
# ### 10. Join words into a single string separated by spaces.

# %%
# Write your answer here
a = "Ponrajan", "Boy"
print(" ".join(a))
# Out:
# Ponrajan Boy

# %% [markdown]
# ### 11. Reverse a string.

# %%
# Write your answer here
a = "Ponrajan"
print(a[::-1])
# Out:
# najarnoP

# %% [markdown]
# ### 12. Check whether a string is a palindrome.

# %%
# Write your answer here
a = "PoP"
if( a == a[::-1]):
    print(a, "palindrome")
else:
    print(a, "not palindrome")
# Out:
# PoP palindrome

# %% [markdown]
# ### 13. Extract the first 5 characters from a string.

# %%
# Write your answer here
a = "Ponrajan"
print(a[0:5])
print(a[0:1])
# Out:
# Ponra
# P

# %% [markdown]
# ### 14. Extract the last 3 characters from a string.

# %%
# Write your answer here
a = "Ponrajan"
print(a[-5:])
# Out:
# rajan

# %% [markdown]
# ### 15. Find the index position of a character in a string.

# %%
# Write your answer here
a = "Ponrajan"
print(a.index("a"))
# Out:
# 4

# %% [markdown]
# ### 16. Check if a string starts with a specific word.

# %%
# Write your answer here
a = "Ponrajan"
b = "P"
print(a.startswith(b))
# Out:
# True

# %% [markdown]
# ### 17. Check if a string ends with a specific word.

# %%
# Write your answer here
# Write your answer here
a = "Ponrajan"
b = "n"
print(a.endswith(b))
# Out:
# True

# %% [markdown]
# ### 18. Capitalize the first letter of a string.

# %%
# Write your answer here
a = "ponrajan"
print(a.capitalize())
# Out:
# Ponrajan

# %% [markdown]
# ### 19. Swap uppercase letters to lowercase and vice versa.

# %%
# Write your answer here
a = "poNrajan"
print(a.swapcase())
# Out:
# POnRAJAN

# %% [markdown]
# ### 20. Remove all vowels from a string.

# %%
# Write your answer here
