# %% [markdown]
# # Python Loop Practice – 20 Questions
#
# This notebook contains two sets of Python loop questions:
# - **Set 1 (Q1–Q10):** Nested loops with two inner loops inside a main loop.
# - **Set 2 (Q11–Q20):** Nested loop followed by a single outer loop.
#
# Try predicting the outputs or answering the questions before running the code!

# %% [markdown]
# #**Q1:**
# #What is the output of this code?
# for i in range(1, 3):
#     for j in range(10, 12):
#         print(i, j)
#     for k in range(20, 22):
#         print(i, k)

# %%
for i in range(1, 3):
    for j in range(10, 12):
        print(i, j)
    for k in range(20, 22):
        print(i, k)
# Out:
# 1 10
# 1 11
# 1 20
# 1 21
# 2 10
# 2 11
# 2 20
# 2 21

# %% [markdown]
# **Q2:**
# How many total lines will this print?
# ```python
# for x in range(2):
#     for y in range(3, 5):
#         print(x, y)
#     for z in range(6, 8):
#         print(x, z)
# ```

# %%
for x in range(2):
    for y in range(3, 5):
        print(x, y)
    for z in range(6, 8):
        print(x, z)
# Out:
# 0 3
# 0 4
# 0 6
# 0 7
# 1 3
# 1 4
# 1 6
# 1 7

# %% [markdown]
# **Q3:**
# Predict the output:
# ```python
# for a in range(1, 3):
#     for b in range(100, 103):
#         print(a * b)
#     for c in range(1, 3):
#         print(a + c)
# ```

# %%
for a in range(1, 3):
    for b in range(100, 103):
        print(a * b)
    for c in range(1, 3):
        print(a + c)
# Out:
# 100
# 101
# 102
# 2
# 3
# 200
# 202
# 204
# 3
# 4

# %%
for x in range(2):
    for y in range(3, 5):
        print(x, y)
    for z in range(6, 8):
        print(x, z)
# Out:
# 0 3
# 0 4
# 0 6
# 0 7
# 1 3
# 1 4
# 1 6
# 1 7

# %% [markdown]
# **Q4:**
# How many times will `print(i, j)` and `print(i, k)` run in total?
# ```python
# for i in range(2, 4):
#     for j in range(1, 4):
#         print(i, j)
#     for k in range(5, 8):
#         print(i, k)
# ```

# %%
for i in range(2, 4):
    for j in range(1, 4):
        print(i, j)
    for k in range(5, 8):
        print(i, k)
# Out:
# 2 1
# 2 2
# 2 3
# 2 5
# 2 6
# 2 7
# 3 1
# 3 2
# 3 3
# 3 5
# 3 6
# 3 7

# %% [markdown]
# **Q5:**
# What’s the final output value printed?
# ```python
# for m in range(3):
#     for n in range(1, 2):
#         print(m + n)
#     for p in range(5, 6):
#         print(m * p)
# ```

# %%
for m in range(3):
    for n in range(1, 2):
        print(m + n)
    for p in range(5, 6):
        print(m * p)
# Out:
# 1
# 0
# 2
# 5
# 3
# 10

# %% [markdown]
# **Q6:**
# Which values are printed in the second loop?
# ```python
# for i in range(1, 2):
#     for j in range(4, 6):
#         print(i, j)
#     for k in range(7, 9):
#         print(i, k)
# ```

# %%
for i in range(1, 2):
    for j in range(4, 6):
        print(i, j)
    for k in range(7, 9):
        print(i, k)
# Out:
# 1 4
# 1 5
# 1 7
# 1 8

# %% [markdown]
# **Q7:**
# Fill in the blank: This prints ______ total lines.
# ```python
# for a in range(3):
#     for b in range(2):
#         print(a, b)
#     for c in range(4):
#         print(a, c)
# ```

# %%
for a in range(3):
    for b in range(2):
        print(a, b)
    for c in range(4):
        print(a, c)
# Out:
# 0 0
# 0 1
# 0 0
# 0 1
# 0 2
# 0 3
# 1 0
# 1 1
# 1 0
# 1 1
# 1 2
# 1 3
# 2 0
# 2 1
# 2 0
# 2 1
# 2 2
# 2 3

# %% [markdown]
# **Q8:**
# What is printed when `i = 1`?
# ```python
# for i in range(2):
#     for j in range(10, 11):
#         print(i, j)
#     for k in range(20, 21):
#         print(i, k)
# ```

# %%
for i in range(2):
    for j in range(10, 11):
        print(i, j)
    for k in range(20, 21):
        print(i, k)
# Out:
# 0 10
# 0 20
# 1 10
# 1 20

# %% [markdown]
# **Q9:**
# How does the inner loop affect the output order?
# ```python
# for x in range(2):
#     for y in range(5, 7):
#         print("X:", x, "Y:", y)
#     for z in range(8, 10):
#         print("X:", x, "Z:", z)
# ```

# %%
for x in range(2):
    for y in range(5, 7):
        print("X:", x, "Y:", y)
    for z in range(8, 10):
        print("X:", x, "Z:", z)
# Out:
# X: 0 Y: 5
# X: 0 Y: 6
# X: 0 Z: 8
# X: 0 Z: 9
# X: 1 Y: 5
# X: 1 Y: 6
# X: 1 Z: 8
# X: 1 Z: 9

# %% [markdown]
# **Q10:**
# Which pairs are printed last?
# ```python
# for a in range(1, 3):
#     for b in range(3, 4):
#         print(a, b)
#     for c in range(5, 7):
#         print(a, c)
# ```

# %%
for a in range(1, 3):
    for b in range(3, 4):
        print(a, b)
    for c in range(5, 7):
        print(a, c)
# Out:
# 1 3
# 1 5
# 1 6
# 2 3
# 2 5
# 2 6

# %% [markdown]
# **Q11:**
# What does this code print last?
# ```python
# for i in range(2):
#     for j in range(4, 6):
#         print(i, j)
# for k in range(7, 9):
#     print(k)
# ```

# %%
for i in range(2):
    for j in range(4, 6):
        print(i, j)
for k in range(7, 9):
    print(k)
# Out:
# 0 4
# 0 5
# 1 4
# 1 5
# 7
# 8

# %% [markdown]
# **Q12:**
# How many total print calls are executed?
# ```python
# for x in range(2):
#     for y in range(3):
#         print(x, y)
# for z in range(2):
#     print(z)
# ```

# %%
for x in range(2):
    for y in range(3):
        print(x, y)
for z in range(2):
    print(z)
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2
# 0
# 1

# %% [markdown]
# **Q13:**
# What is the first value printed by the final loop?
# ```python
# for a in range(3):
#     for b in range(5, 6):
#         print(a, b)
# for c in range(9, 12):
#     print(c)
# ```

# %%
for a in range(3):
    for b in range(5, 6):
        print(a, b)
for c in range(9, 12):
    print(c)
# Out:
# 0 5
# 1 5
# 2 5
# 9
# 10
# 11

# %% [markdown]
# **Q14:**
# What are the last 3 numbers printed?
# ```python
# for i in range(1):
#     for j in range(2, 4):
#         print(i, j)
# for k in range(10, 15):
#     print(k)
# ```

# %%
for i in range(1):
    for j in range(2, 4):
        print(i, j)
for k in range(10, 15):
    print(k)
# Out:
# 0 2
# 0 3
# 10
# 11
# 12
# 13
# 14

# %% [markdown]
# **Q15:**
# What is the value of `z` in the final print loop?
# ```python
# for x in range(1, 3):
#     for y in range(2):
#         print(x, y)
# for z in range(6, 9):
#     print(z)
# ```

# %%
for x in range(1, 3):
    for y in range(2):
        print(x, y)
for z in range(6, 9):
    print(z)
# Out:
# 1 0
# 1 1
# 2 0
# 2 1
# 6
# 7
# 8

# %% [markdown]
# **Q16:**
# How many times will "print(z)" be called?
# ```python
# for a in range(4):
#     for b in range(3, 5):
#         print(a, b)
# for z in range(2, 7):
#     print(z)
# ```

# %%
for a in range(4):
    for b in range(3, 5):
        print(a, b)
for z in range(2, 7):
    print(z)
# Out:
# 0 3
# 0 4
# 1 3
# 1 4
# 2 3
# 2 4
# 3 3
# 3 4
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# **Q17:**
# Which line comes immediately after `print(1, 5)`?
# ```python
# for x in range(2):
#     for y in range(5, 7):
#         print(x, y)
# for z in range(9, 11):
#     print(z)
# ```

# %%
for x in range(2):
    for y in range(5, 7):
        print(x, y)
for z in range(9, 11):
    print(z)
# Out:
# 0 5
# 0 6
# 1 5
# 1 6
# 9
# 10

# %% [markdown]
# **Q18:**
# What is the total number of values printed?
# ```python
# for i in range(2):
#     for j in range(2):
#         print(i, j)
# for k in range(4):
#     print(k)
# ```

# %%
for i in range(2):
    for j in range(2):
        print(i, j)
for k in range(4):
    print(k)
# Out:
# 0 0
# 0 1
# 1 0
# 1 1
# 0
# 1
# 2
# 3

# %% [markdown]
# **Q19:**
# What is the output order of this code?
# ```python
# for m in range(1):
#     for n in range(2):
#         print(m, n)
# for p in range(3):
#     print(p)
# ```

# %%
for m in range(1):
    for n in range(2):
        print(m, n)
for p in range(3):
    print(p)
# Out:
# 0 0
# 0 1
# 0
# 1
# 2

# %% [markdown]
# **Q20:**
# Which numbers appear in both inner and outer loops?
# ```python
# for i in range(2):
#     for j in range(4, 7):
#         print(j)
# for k in range(5, 9):
#     print(k)
# ```

# %%
for i in range(2):
    for j in range(4, 7):
        print(j)
for k in range(5, 9):
    print(k)
# Out:
# 4
# 5
# 6
# 4
# 5
# 6
# 5
# 6
# 7
# 8
